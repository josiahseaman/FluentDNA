# %% [markdown]
# # Stats for Syntenic versus Translocation from Chain file
# We want to know how much of the alignment is a syntenic transfer 1:1 and how many bp have been rearranged between the two genomes.

# %%
from FluentDNA.ChainFiles import chain_file_to_list, fetch_all_chains, Chain, ChainEntry
from DNASkittleUtils.DDVUtils import pp

# %%
contig_names = 'chr1 chr2 chr3 chr4 chr5 chr6 chr7 chr8 chr9 chr10 chr11 chr12 chr13 chr14 chr15 chr16 chr17 chr18 chr19 chr20 chr21 chr22 chrX chrY'.split()
chain_path = r"D:\Genomes\Human\alignments\hg38ToPanTro6.over.chain"
headers = chain_file_to_list(chain_path, contig_names)  # just read the headers and discard the rest
len(headers)
# Out:
# 28612

# %%
pp(sum([e.size for e in headers[0].entries]))
# Out:
# '124,837,690'

# %% [markdown]
# The actual coverage tends to be slightly less than the list "query Size" which includes gaps. It appears chain Score is not bp at all.  Likely this is a z-score.

# %% [markdown]
# Sizes include difference already summed in.  I only know the % identity or total number of shared bp.  I don't know how that divides between my 3 categories, though if I assume it was evenly distributed, you could estimate shared bp in each category.  If I went through the unique sequence after having collapsed all ref gaps, then I'd have the exact number, since differences need not be attributed to a particular category.  We can switch to the translocations + non_syntenic + primary_chain that I've already calculated when we want to include differences.  "No Coverage" is already known.
# **Conclusion**: These stats are all coverage, not shared bp or identity.

# %%
chain_stats = {name: {} for name in contig_names}
chr2_chains = fetch_all_chains('chr2', 'chr2B', None, headers) +\
            fetch_all_chains('chr2', 'chr2A', None, headers)  # special case chr2
chr2_chains.sort(key=lambda chain: -chain.score)

for chromosome in contig_names:
    relevant = fetch_all_chains(chromosome, chromosome, None, headers)
    if chromosome == 'chr2':
        relevant = chr2_chains
    chain_stats[chromosome]['Primary Chain'] = sum([e.size for e in relevant[0].entries])
    non_syntenic = sum([e.size for chain in relevant[1:] for e in chain.entries]) if len(relevant) > 1 else 0
    chain_stats[chromosome]['Non-syntenic Same Chromosome'] = non_syntenic
    transloc_chains = fetch_all_chains(chromosome, None, None, headers)
    if chromosome == 'chr2':  # don't count chr2A and chr2B as different
        transloc_chains = [c for c in transloc_chains if c.qName not in ['chr2A', 'chr2B']]
    translocations = sum([e.size for chain in transloc_chains for e in chain.entries if chain.qName != chromosome])
    chain_stats[chromosome]['Translocation from Other Chromosomes'] =  translocations
    chain_stats[chromosome]['First Two Chains'] = sum([e.size for chain in relevant[:2] for e in chain.entries])
    chain_stats[chromosome]['First Three Chains'] = sum([e.size for chain in relevant[:3] for e in chain.entries])
# Out:
# chr2 chr2B None : 478
# chr2 chr2A None : 798
# chr1 chr1 None : 1168
# chr1 None None : 1710
# chr2 chr2 None : 0
# chr2 None None : 1610
# chr3 chr3 None : 473
# chr3 None None : 661
# chr4 chr4 None : 859
# chr4 None None : 1126
# chr5 chr5 None : 811
# chr5 None None : 1206
# chr6 chr6 None : 797
# chr6 None None : 966
# chr7 chr7 None : 1262
# chr7 None None : 1643
# chr8 chr8 None : 927
# chr8 None None : 1135
# chr9 chr9 None : 588
# chr9 None None : 996
# chr10 chr10 None : 929
# chr10 None None : 1209
# chr11 chr11 None : 554
# chr11 None None : 701
# chr12 chr12 None : 613
# chr12 None None : 719
# chr13 chr13 None : 529
# chr13 None None : 701
# chr14 chr14 None : 477
# chr14 None None : 631
# chr15 chr15 None : 263
# chr15 None None : 461
# chr16 chr16 None : 752
# chr16 None None : 1105
# chr17 chr17 None : 748
# chr17 None None : 1003
# chr18 chr18 None : 586
# chr18 None None : 677
# chr19 chr19 None : 818
# chr19 None None : 986
# chr20 chr20 None : 505
# chr20 None None : 616
# chr21 chr21 None : 298
# chr21 None None : 541
# chr22 chr22 None : 530
# chr22 None None : 777
# chrX chrX None : 590
# chrX None None : 1488
# chrY chrY None : 313
# chrY None None : 1592

# %%
import pandas as pd 
df = pd.DataFrame(chain_stats) 
df.to_csv(r"D:\Genomes\Human\alignments\hg38ToPanTro6_stats.csv")
df.head()
# Out:
#                                            chr1      chr10      chr11  \
# First Three Chains                    212843994  124487884  125843504
# First Two Chains                      188398140  123980669   94011435
# Non-syntenic Same Chromosome          104081729   39823372   78975113
# Primary Chain                         114984699   86709438   48114280
# Translocation from Other Chromosomes    3834877    1315050     571079
#
#                                           chr12     chr13     chr14     chr15  \
# First Three Chains                    105788978  89790006  85221470  75656180
# First Two Chains                       92381491  87445742  85180600  73889080
# Non-syntenic Same Chromosome           63938230  31162967    513209  10205552
# Primary Chain                          63230073  62370844  85021656  69081961
# Translocation from Other Chromosomes     470757    745723    924394   1200080
#
#                                          chr16     chr17     chr18    ...     \
# First Three Chains                    64139961  61506966  72710459    ...
# First Two Chains                      55223212  51635953  72705936    ...
# Non-syntenic Same Chromosome          34476637  41881749  14511023    ...
# Primary Chain                         38655719  33475161  58288802    ...
# Translocation from Other Chromosomes   4884563   1417764    635990    ...
#
#                                          chr22       chr3       chr4  \
# First Three Chains                    31328200  191117095  149671593
# First Two Chains                      29855569  191036976  127701947
# Non-syntenic Same Chromosome           5221818   89029377   79986252
# Primary Chain                         27760708  102292762  102404731
# Translocation from Other Chromosomes   2766733     625415    1545241
#
#                                            chr5       chr6       chr7  \
# First Three Chains                     95936882  164380573  144691258
# First Two Chains                       71133305  161361608  140387084
# Non-syntenic Same Chromosome          112038574   56884384   59326241
# Primary Chain                          44644988  107751895   90353609
# Translocation from Other Chromosomes   17266605    1045473    2340038
#
#                                            chr8       chr9       chrX  \
# First Three Chains                    126838817  107005608  109515825
# First Two Chains                       96497462   89454020   82867553
# Non-syntenic Same Chromosome           80149115   60177384   95470175
# Primary Chain                          58120074   50569308   48866364
# Translocation from Other Chromosomes    1021778    5328211     744372
#
#                                           chrY
# First Three Chains                     9056820
# First Two Chains                       7299314
# Non-syntenic Same Chromosome          11040058
# Primary Chain                          4507514
# Translocation from Other Chromosomes   7456790
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Double Check sequence lengths with Ns

# %%
from DNASkittleUtils.Contigs import Contig, read_contigs
hg38 = read_contigs(r"D:\Genomes\Human\hg38.fa")

# %%
for contig in hg38:
    if contig.name in contig_names:
        chain_stats[contig.name]['Total Length'] = len(contig.seq)
        chain_stats[contig.name]['Total Length (No Ns)'] = len(contig.seq) - contig.seq.count('N') - contig.seq.count('n')

df = pd.DataFrame(chain_stats) 
df = df[contig_names] # reorder columns
df.to_csv(r"D:\Genomes\Human\alignments\hg38ToPanTro6_stats.csv")
df
# Out:
#                                            chr1       chr2       chr3  \
# First Three Chains                    212843994  211287080  191117095
# First Two Chains                      188398140  195592657  191036976
# Non-syntenic Same Chromosome          104081729  107244972   89029377
# Primary Chain                         114984699  124837690  102292762
# Total Length                          248956422  242193529  198295559
# Total Length (No Ns)                  230481012  240548228  198100135
# Translocation from Other Chromosomes    3834877    1490781     625415
#
#                                            chr4       chr5       chr6  \
# First Three Chains                    149671593   95936882  164380573
# First Two Chains                      127701947   71133305  161361608
# Non-syntenic Same Chromosome           79986252  112038574   56884384
# Primary Chain                         102404731   44644988  107751895
# Total Length                          190214555  181538259  170805979
# Total Length (No Ns)                  189752667  181265378  170078522
# Translocation from Other Chromosomes    1545241   17266605    1045473
#
#                                            chr7       chr8       chr9  \
# First Three Chains                    144691258  126838817  107005608
# First Two Chains                      140387084   96497462   89454020
# Non-syntenic Same Chromosome           59326241   80149115   60177384
# Primary Chain                          90353609   58120074   50569308
# Total Length                          159345973  145138636  138394717
# Total Length (No Ns)                  158970131  144768136  121790550
# Translocation from Other Chromosomes    2340038    1021778    5328211
#
#                                           chr10    ...         chr15  \
# First Three Chains                    124487884    ...      75656180
# First Two Chains                      123980669    ...      73889080
# Non-syntenic Same Chromosome           39823372    ...      10205552
# Primary Chain                          86709438    ...      69081961
# Total Length                          133797422    ...     101991189
# Total Length (No Ns)                  133262962    ...      84641325
# Translocation from Other Chromosomes    1315050    ...       1200080
#
#                                          chr16     chr17     chr18     chr19  \
# First Three Chains                    64139961  61506966  72710459  51430338
# First Two Chains                      55223212  51635953  72705936  50516523
# Non-syntenic Same Chromosome          34476637  41881749  14511023  24405460
# Primary Chain                         38655719  33475161  58288802  28339269
# Total Length                          90338345  83257441  80373285  58617616
# Total Length (No Ns)                  81805943  82920204  80089605  58440758
# Translocation from Other Chromosomes   4884563   1417764    635990    444370
#
#                                          chr20     chr21     chr22       chrX  \
# First Three Chains                    58095027  32627633  31328200  109515825
# First Two Chains                      57763891  32473339  29855569   82867553
# Non-syntenic Same Chromosome          26698533    783172   5221818   95470175
# Primary Chain                         32528719  32285226  27760708   48866364
# Total Length                          64444167  46709983  50818468  156040895
# Total Length (No Ns)                  63944257  40088619  39159777  154893029
# Translocation from Other Chromosomes    395480   3390981   2766733     744372
#
#                                           chrY
# First Three Chains                     9056820
# First Two Chains                       7299314
# Non-syntenic Same Chromosome          11040058
# Primary Chain                          4507514
# Total Length                          57227415
# Total Length (No Ns)                  26415043
# Translocation from Other Chromosomes   7456790
#
# [7 rows x 24 columns]

# %% [markdown]
# # Gather Alignment Stats into a single File
# This functionality has been partially integrated into FluentDNA for derived stats.

# %%
# Specify your target directory
# Traverse directory
# parse files to dict structure
# Compute derivative values
# Print medians

# %%
import os
from os.path import dirname, join
from glob import glob 
from statistics import median

# %%
def print_median(name, label, key, contents):
    print(name, label, "{:0.2%}".format(median([contents[d][key] for d in contents.keys()])))
    
def print_average(name, label, key, contents):
    avg = 0
    total_length = 0
    genome_length = sum([v["Ref Chr Total Size (No N's)"] for k,v in contents.items()])
    for chr in contents.keys():
        avg += contents[chr][key] * contents[chr]["Ref Chr Total Size (No N's)"] / genome_length
    print(name, label, "{:0.2%}".format(avg))

def summarize_stats(name, contents):
#     print("Median Chromosome Value")
#     print_median(name, 'identity', 'Ref Identity within Alignment', contents)
#     print_median(name, 'coverage', 'Alignment Coverage of Ref Chr', contents)
#     print_median(name, 'query coverage', "Alignment Coverage of Query Main Chr", contents)
    
    print_average(name, 'identity', 'Ref Identity within Alignment', contents)
    print_average(name, 'coverage', 'Alignment Coverage of Ref Chr', contents)
#     print_average(name, 'query coverage', "Alignment Coverage of Query Main Chr", contents)

# %%
def number(string):
    try:
        return int(string)
    except ValueError:
        return float(string)
    
def collect_stats(folder, prefix=''):
    contents = {}
      # Specify you target directory
    os.chdir(folder)
    # Traverse directory
    subdirs = glob(prefix + '*')
    for d in subdirs:
        stats_file = os.path.join(d, r'stats.txt')
        if os.path.exists(stats_file):
            with open(stats_file) as stat:
                # parse files to dict structure
                lines = [line.split('\t') for line in stat.read().splitlines()]
                v = {line[0]: number(line[1]) for line in lines if len(line) == 2}
                # Compute derivative values
                v["Total alignment Length"] = v['Aligned Variance in bp'] + v['Shared seq bp']
                v["Ref Chr Total Size (No N's)"] = v['Ref unique bp'] + v["Total alignment Length"]
                v["Ref Identity within Alignment"] = 1 - (v['Aligned Variance in bp'] / v['Total alignment Length'])
                v["Alignment Coverage of Ref Chr"] = v["Total alignment Length"] / v["Ref Chr Total Size (No N's)"]
                v["Alignment Coverage of Query Main Chr"] = v['Total alignment Length'] / (v['Total alignment Length'] + v["Query unique bp"])
                contents[d] = v
    # Print medians
    name = prefix or os.path.basename(folder)
#     print("Averages Weighted by Chromosome Length")
    summarize_stats(name, contents)
    return contents

# %%
root = r'E:\Projects\FluentDNA-2.4.1\www-data\dnadata'
# folder = os.path.join(root, )
genome = collect_stats(root, prefix='Human Hg38 vs Chimpanzee PanTro6_')
for name, stats in genome.items():
    print(f"\n\n{name[33:]}")
    for k,v in stats.items():
        print(f'{k}\t{v}')
# Out:
# Human Hg38 vs Chimpanzee PanTro6_ identity 98.65%
# Human Hg38 vs Chimpanzee PanTro6_ coverage 94.95%
#
#
# chr1
# Ref Number of Gaps (all)	165609
# Ref Gaps larger than 10bp	18763
# Query Number of Gaps (all)	171053
# Query Gaps larger than 10bp	21270
# Ref Gaps larger than 100bp	4479
# Query Gaps larger than 100bp	4832
# Ref Gaps larger than 1000bp	1655
# Query Gaps larger than 1000bp	1943
# Ref N to query bp	18475471
# Ref unique bp	8720120
# Shared seq bp	220917707
# Aligned Variance in bp	2830836
# Query unique bp	8724657
# Query N to ref in bp	2495044
# Total alignment Length	223748543
# Ref Chr Total Size (No N's)	232468663
# Ref Identity within Alignment	0.9873481366088717
# Alignment Coverage of Ref Chr	0.9624890516964001
# Alignment Coverage of Query Main Chr	0.9624702675405165
#
#
# chr10
# Query Number of Gaps (all)	98327
# Query Gaps larger than 10bp	12245
# Ref Number of Gaps (all)	95484
# Ref Gaps larger than 10bp	11050
# Query Gaps larger than 100bp	2354
# Query Gaps larger than 1000bp	620
# Ref Gaps larger than 100bp	2504
# Ref Gaps larger than 1000bp	819
# Ref N to query bp	534460
# Ref unique bp	6082908
# Shared seq bp	126144862
# Aligned Variance in bp	1708138
# Query unique bp	4145888
# Query N to ref in bp	1197562
# Total alignment Length	127853000
# Ref Chr Total Size (No N's)	133935908
# Ref Identity within Alignment	0.986639828553104
# Alignment Coverage of Ref Chr	0.9545834415069632
# Alignment Coverage of Query Main Chr	0.9685914929828803
#
#
# chr11
# Query Number of Gaps (all)	94230
# Ref Number of Gaps (all)	92132
# Query Gaps larger than 10bp	10997
# Query Gaps larger than 100bp	1996
# Query Gaps larger than 1000bp	598
# Ref Gaps larger than 10bp	9946
# Ref Gaps larger than 100bp	1971
# Ref Gaps larger than 1000bp	677
# Ref N to query bp	552880
# Shared seq bp	126357568
# Aligned Variance in bp	1694144
# Ref unique bp	7284509
# Query unique bp	2765835
# Query N to ref in bp	8258
# Total alignment Length	128051712
# Ref Chr Total Size (No N's)	135336221
# Ref Identity within Alignment	0.986769844982627
# Alignment Coverage of Ref Chr	0.9461747273111756
# Alignment Coverage of Query Main Chr	0.9788573087981844
#
#
# chr12
# Ref Number of Gaps (all)	96419
# Query Number of Gaps (all)	98479
# Ref Gaps larger than 10bp	9907
# Ref Gaps larger than 100bp	1901
# Query Gaps larger than 10bp	11165
# Ref Gaps larger than 1000bp	586
# Query Gaps larger than 100bp	1887
# Query Gaps larger than 1000bp	465
# Ref N to query bp	137493
# Ref unique bp	6103971
# Shared seq bp	126059664
# Aligned Variance in bp	1618815
# Query unique bp	1956826
# Query N to ref in bp	5774
# Total alignment Length	127678479
# Ref Chr Total Size (No N's)	133782450
# Ref Identity within Alignment	0.987321160052353
# Alignment Coverage of Ref Chr	0.9543739033034602
# Alignment Coverage of Query Main Chr	0.9849051460171286
#
#
# chr13
# Ref Number of Gaps (all)	71882
# Query Number of Gaps (all)	74740
# Query Gaps larger than 10bp	8273
# Query Gaps larger than 100bp	1586
# Ref Gaps larger than 10bp	7416
# Ref Gaps larger than 100bp	1638
# Ref Gaps larger than 1000bp	506
# Query Gaps larger than 1000bp	408
# Ref N to query bp	16381203
# Ref unique bp	3849601
# Shared seq bp	93347690
# Aligned Variance in bp	1250938
# Query unique bp	5205275
# Query N to ref in bp	402562
# Total alignment Length	94598628
# Ref Chr Total Size (No N's)	98448229
# Ref Identity within Alignment	0.9867763621265205
# Alignment Coverage of Ref Chr	0.9608972041538706
# Alignment Coverage of Query Main Chr	0.9478449755617273
#
#
# chr14
# Query Number of Gaps (all)	66865
# Query Gaps larger than 10bp	7557
# Ref Number of Gaps (all)	65255
# Query Gaps larger than 100bp	1328
# Query Gaps larger than 1000bp	440
# Ref Gaps larger than 10bp	6801
# Ref Gaps larger than 100bp	1370
# Ref Gaps larger than 1000bp	462
# Ref N to query bp	16475569
# Ref unique bp	4245909
# Shared seq bp	85325045
# Query unique bp	2098847
# Aligned Variance in bp	1134250
# Query N to ref in bp	475733
# Total alignment Length	86459295
# Ref Chr Total Size (No N's)	90705204
# Ref Identity within Alignment	0.9868811097754151
# Alignment Coverage of Ref Chr	0.9531900176311825
# Alignment Coverage of Query Main Chr	0.9762997850609829
#
#
# chr15
# Query Number of Gaps (all)	66261
# Ref Number of Gaps (all)	63744
# Query Gaps larger than 10bp	7551
# Ref Gaps larger than 10bp	6843
# Query Gaps larger than 100bp	1404
# Query Gaps larger than 1000bp	478
# Ref Gaps larger than 100bp	1455
# Ref Gaps larger than 1000bp	578
# Ref N to query bp	17349864
# Ref unique bp	4447223
# Shared seq bp	79377739
# Aligned Variance in bp	1110620
# Query unique bp	9776198
# Query N to ref in bp	1518735
# Total alignment Length	80488359
# Ref Chr Total Size (No N's)	84935582
# Ref Identity within Alignment	0.9862014828753062
# Alignment Coverage of Ref Chr	0.9476400479601117
# Alignment Coverage of Query Main Chr	0.8916939458308093
#
#
# chr16
# Query Number of Gaps (all)	70208
# Query Gaps larger than 10bp	10578
# Ref Number of Gaps (all)	66458
# Ref Gaps larger than 10bp	9996
# Ref Gaps larger than 100bp	2892
# Query Gaps larger than 100bp	2723
# Ref Gaps larger than 1000bp	1127
# Query Gaps larger than 1000bp	969
# Ref N to query bp	8533476
# Ref unique bp	4824479
# Shared seq bp	76802346
# Query unique bp	8134807
# Aligned Variance in bp	1219533
# Query N to ref in bp	355075
# Total alignment Length	78021879
# Ref Chr Total Size (No N's)	82846358
# Ref Identity within Alignment	0.9843693459369263
# Alignment Coverage of Ref Chr	0.9417659494458405
# Alignment Coverage of Query Main Chr	0.9055812453139156
#
#
# chr17
# Query Number of Gaps (all)	64542
# Ref Number of Gaps (all)	64312
# Query Gaps larger than 10bp	8707
# Ref Gaps larger than 10bp	8164
# Query Gaps larger than 100bp	1727
# Ref Gaps larger than 100bp	1826
# Ref Gaps larger than 1000bp	598
# Query Gaps larger than 1000bp	550
# Ref N to query bp	337994
# Shared seq bp	75807242
# Aligned Variance in bp	1004791
# Query unique bp	33191258
# Ref unique bp	6846475
# Query N to ref in bp	853093
# Total alignment Length	76812033
# Ref Chr Total Size (No N's)	83658508
# Ref Identity within Alignment	0.9869188334072605
# Alignment Coverage of Ref Chr	0.9181616411327823
# Alignment Coverage of Query Main Chr	0.6982703181125736
#
#
# chr18
# Ref Number of Gaps (all)	55079
# Query Number of Gaps (all)	56834
# Query Gaps larger than 10bp	6424
# Ref Gaps larger than 10bp	5861
# Query Gaps larger than 100bp	1148
# Ref Gaps larger than 100bp	1129
# Query Gaps larger than 1000bp	283
# Ref Gaps larger than 1000bp	323
# Ref N to query bp	283680
# Ref unique bp	6855876
# Shared seq bp	72457276
# Aligned Variance in bp	978685
# Query unique bp	1233057
# Query N to ref in bp	421540
# Total alignment Length	73435961
# Ref Chr Total Size (No N's)	80291837
# Ref Identity within Alignment	0.9866729462422368
# Alignment Coverage of Ref Chr	0.9146130384337825
# Alignment Coverage of Query Main Chr	0.9834863637820976
#
#
# chr19
# Ref Number of Gaps (all)	53722
# Ref Gaps larger than 10bp	7683
# Query Number of Gaps (all)	54235
# Query Gaps larger than 10bp	8220
# Query Gaps larger than 100bp	1978
# Query Gaps larger than 1000bp	608
# Ref Gaps larger than 100bp	1990
# Ref Gaps larger than 1000bp	667
# Ref N to query bp	176858
# Shared seq bp	52358698
# Aligned Variance in bp	831326
# Ref unique bp	5993312
# Query unique bp	2981850
# Query N to ref in bp	509942
# Total alignment Length	53190024
# Ref Chr Total Size (No N's)	59183336
# Ref Identity within Alignment	0.9843706406299045
# Alignment Coverage of Ref Chr	0.898733116362349
# Alignment Coverage of Query Main Chr	0.946915604061919
#
#
# chr2
# Ref Number of Gaps (all)	170672
# Query Number of Gaps (all)	178311
# Query Gaps larger than 10bp	20429
# Ref Gaps larger than 10bp	18015
# Ref Gaps larger than 100bp	3618
# Query Gaps larger than 100bp	3701
# Query Gaps larger than 1000bp	1068
# Ref Gaps larger than 1000bp	1187
# Ref N to query bp	1645301
# Ref unique bp	8260400
# Shared seq bp	230534885
# Aligned Variance in bp	3039716
# Query unique bp	4682573
# Query N to ref in bp	512888
# Total alignment Length	233574601
# Ref Chr Total Size (No N's)	241835001
# Ref Identity within Alignment	0.9869861021404464
# Alignment Coverage of Ref Chr	0.9658428268619397
# Alignment Coverage of Query Main Chr	0.9803465603096594
#
#
# chr20
# Query Number of Gaps (all)	47098
# Ref Number of Gaps (all)	45779
# Query Gaps larger than 10bp	6115
# Ref Gaps larger than 10bp	5898
# Ref Gaps larger than 100bp	1291
# Query Gaps larger than 100bp	1104
# Ref Gaps larger than 1000bp	405
# Query Gaps larger than 1000bp	335
# Ref N to query bp	500575
# Shared seq bp	58788482
# Aligned Variance in bp	834315
# Query unique bp	1090382
# Ref unique bp	4674499
# Query N to ref in bp	65675
# Total alignment Length	59622797
# Ref Chr Total Size (No N's)	64297296
# Ref Identity within Alignment	0.9860067785816892
# Alignment Coverage of Ref Chr	0.9272986689829071
# Alignment Coverage of Query Main Chr	0.9820404396877324
#
#
# chr21
# Query Number of Gaps (all)	35036
# Ref Number of Gaps (all)	33180
# Ref Gaps larger than 10bp	4281
# Query Gaps larger than 10bp	4377
# Query Gaps larger than 100bp	909
# Query Gaps larger than 1000bp	323
# Ref Gaps larger than 100bp	1027
# Ref Gaps larger than 1000bp	326
# Ref N to query bp	6621364
# Shared seq bp	35871105
# Aligned Variance in bp	588978
# Query unique bp	910924
# Ref unique bp	3798511
# Query N to ref in bp	180762
# Total alignment Length	36460083
# Ref Chr Total Size (No N's)	40258594
# Ref Identity within Alignment	0.9838459501038437
# Alignment Coverage of Ref Chr	0.9056472016881663
# Alignment Coverage of Query Main Chr	0.9756248473582743
#
#
# chr22
# Query Number of Gaps (all)	35142
# Ref Number of Gaps (all)	33888
# Query Gaps larger than 10bp	5098
# Query Gaps larger than 100bp	1200
# Query Gaps larger than 1000bp	443
# Ref Gaps larger than 10bp	5000
# Ref Gaps larger than 100bp	1311
# Ref Gaps larger than 1000bp	481
# Ref N to query bp	11659387
# Shared seq bp	35177263
# Aligned Variance in bp	598637
# Ref unique bp	3699846
# Query unique bp	5071519
# Query N to ref in bp	278066
# Total alignment Length	35775900
# Ref Chr Total Size (No N's)	39475746
# Ref Identity within Alignment	0.983267031716882
# Alignment Coverage of Ref Chr	0.9062754634199947
# Alignment Coverage of Query Main Chr	0.8758423635040442
#
#
# chr3
# Ref Number of Gaps (all)	137201
# Query Number of Gaps (all)	142805
# Query Gaps larger than 10bp	15560
# Ref Gaps larger than 10bp	13383
# Ref Gaps larger than 100bp	2374
# Query Gaps larger than 100bp	2525
# Query Gaps larger than 1000bp	662
# Ref Gaps larger than 1000bp	718
# Ref N to query bp	195424
# Ref unique bp	6981350
# Shared seq bp	189497504
# Aligned Variance in bp	2455454
# Query unique bp	2722691
# Query N to ref in bp	454701
# Total alignment Length	191952958
# Ref Chr Total Size (No N's)	198934308
# Ref Identity within Alignment	0.9872080429205994
# Alignment Coverage of Ref Chr	0.9649062543802148
# Alignment Coverage of Query Main Chr	0.9860142189637698
#
#
# chr4
# Query Number of Gaps (all)	145896
# Ref Number of Gaps (all)	139495
# Query Gaps larger than 10bp	15261
# Ref Gaps larger than 10bp	13788
# Ref Gaps larger than 100bp	2773
# Query Gaps larger than 100bp	2840
# Ref Gaps larger than 1000bp	912
# Query Gaps larger than 1000bp	832
# Ref N to query bp	461888
# Ref unique bp	6721519
# Shared seq bp	181435990
# Aligned Variance in bp	2501290
# Query unique bp	3241496
# Query N to ref in bp	880917
# Total alignment Length	183937280
# Ref Chr Total Size (No N's)	190658799
# Ref Identity within Alignment	0.9864013972588918
# Alignment Coverage of Ref Chr	0.9647458232441714
# Alignment Coverage of Query Main Chr	0.9826823528325669
#
#
# chr5
# Ref Number of Gaps (all)	127304
# Query Number of Gaps (all)	131709
# Query Gaps larger than 10bp	14357
# Ref Gaps larger than 10bp	12607
# Ref Gaps larger than 100bp	2396
# Ref Gaps larger than 1000bp	828
# Query Gaps larger than 100bp	2518
# Query Gaps larger than 1000bp	725
# Ref N to query bp	272881
# Ref unique bp	8377245
# Shared seq bp	171933266
# Aligned Variance in bp	2254345
# Query unique bp	30017302
# Query N to ref in bp	712412
# Total alignment Length	174187611
# Ref Chr Total Size (No N's)	182564856
# Ref Identity within Alignment	0.9870579486849957
# Alignment Coverage of Ref Chr	0.9541135945682777
# Alignment Coverage of Query Main Chr	0.853004016607573
#
#
# chr6
# Ref Number of Gaps (all)	123905
# Ref Gaps larger than 10bp	12484
# Query Number of Gaps (all)	125787
# Ref Gaps larger than 100bp	2308
# Ref Gaps larger than 1000bp	688
# Query Gaps larger than 10bp	13711
# Query Gaps larger than 100bp	2331
# Query Gaps larger than 1000bp	633
# Ref N to query bp	727457
# Shared seq bp	163553827
# Aligned Variance in bp	2128352
# Ref unique bp	5024550
# Query unique bp	3922784
# Query N to ref in bp	424267
# Total alignment Length	165682179
# Ref Chr Total Size (No N's)	170706729
# Ref Identity within Alignment	0.9871540076739334
# Alignment Coverage of Ref Chr	0.9705661866439957
# Alignment Coverage of Query Main Chr	0.9768710541801775
#
#
# chr7
# Query Number of Gaps (all)	124269
# Ref Number of Gaps (all)	119253
# Ref Gaps larger than 10bp	14143
# Query Gaps larger than 10bp	15879
# Query Gaps larger than 100bp	3533
# Query Gaps larger than 1000bp	1163
# Ref Gaps larger than 100bp	3573
# Ref Gaps larger than 1000bp	1277
# Ref N to query bp	376941
# Ref unique bp	8153166
# Shared seq bp	149955018
# Aligned Variance in bp	2064825
# Query unique bp	6402326
# Query N to ref in bp	2041529
# Total alignment Length	152019843
# Ref Chr Total Size (No N's)	160173009
# Ref Identity within Alignment	0.9864173981550554
# Alignment Coverage of Ref Chr	0.9490977534173688
# Alignment Coverage of Query Main Chr	0.9595869312962128
#
#
# chr8
# Query Number of Gaps (all)	107404
# Ref Number of Gaps (all)	103879
# Query Gaps larger than 10bp	12314
# Query Gaps larger than 100bp	2183
# Ref Gaps larger than 10bp	11382
# Query Gaps larger than 1000bp	565
# Ref Gaps larger than 100bp	2359
# Ref Gaps larger than 1000bp	739
# Ref N to query bp	370500
# Ref unique bp	6336318
# Shared seq bp	137307451
# Aligned Variance in bp	1984435
# Query unique bp	2323770
# Query N to ref in bp	9448
# Total alignment Length	139291886
# Ref Chr Total Size (No N's)	145628204
# Ref Identity within Alignment	0.9857534056219183
# Alignment Coverage of Ref Chr	0.956489760733436
# Alignment Coverage of Query Main Chr	0.9835910091748613
#
#
# chr9
# Query Number of Gaps (all)	95198
# Ref Number of Gaps (all)	90319
# Ref Gaps larger than 10bp	10275
# Query Gaps larger than 10bp	10949
# Ref Gaps larger than 100bp	2207
# Query Gaps larger than 100bp	2123
# Query Gaps larger than 1000bp	713
# Ref Gaps larger than 1000bp	845
# Ref N to query bp	16604167
# Ref unique bp	6501557
# Shared seq bp	114437369
# Aligned Variance in bp	1639734
# Query unique bp	2009904
# Query N to ref in bp	240403
# Total alignment Length	116077103
# Ref Chr Total Size (No N's)	122578660
# Ref Identity within Alignment	0.9858737515184196
# Alignment Coverage of Ref Chr	0.9469601234015774
# Alignment Coverage of Query Main Chr	0.9829794653022241
#
#
# chrX
# Query Number of Gaps (all)	97074
# Ref Number of Gaps (all)	89016
# Ref Gaps larger than 10bp	10685
# Query Gaps larger than 10bp	11746
# Ref Gaps larger than 100bp	2703
# Ref Gaps larger than 1000bp	1077
# Query Gaps larger than 100bp	2534
# Query Gaps larger than 1000bp	950
# Ref N to query bp	1147971
# Ref unique bp	10676764
# Shared seq bp	143853741
# Aligned Variance in bp	1536778
# Query unique bp	2966721
# Query N to ref in bp	1094639
# Total alignment Length	145390519
# Ref Chr Total Size (No N's)	156067283
# Ref Identity within Alignment	0.9894299985269328
# Alignment Coverage of Ref Chr	0.9315887110048555
# Alignment Coverage of Query Main Chr	0.9800028566182547
#
#
# chrY
# Query Number of Gaps (all)	35425
# Ref Number of Gaps (all)	35422
# Ref Gaps larger than 10bp	7320
# Query Gaps larger than 10bp	7327
# Query Gaps larger than 100bp	3123
# Ref Gaps larger than 100bp	3226
# Ref Gaps larger than 1000bp	1430
# Query Gaps larger than 1000bp	1371
# Ref N to query bp	30813205
# Ref unique bp	4713798
# Shared seq bp	22309259
# Aligned Variance in bp	758461
# Query unique bp	5105610
# Total alignment Length	23067720
# Ref Chr Total Size (No N's)	27781518
# Ref Identity within Alignment	0.9671202442200616
# Alignment Coverage of Ref Chr	0.8303261182488301
# Alignment Coverage of Query Main Chr	0.8187786108351409

# %%
chr_order = 'chr1 chr2 chr3 chr4 chr5 chr6 chr7 chr8 chr9 chr10 chr11 chr12 chr13 chr14 chr15 chr16 chr17 chr18 chr19 chr20 chr21 chr22 chrX chrY'.split()
prefix = 'Human Hg38 vs Chimpanzee PanTro6_'
labels = list(genome['Human Hg38 vs Chimpanzee PanTro6_chr1'].keys())
print(labels)
print('\t'.join(chr_order))
for label in labels:
    if label:
        print(label, end='\t')
        for c in chr_order:
            
            v = genome[prefix + c][label] if label in genome[prefix + c] else 0
            print(v, end='\t')
        print()
# Out:
# ['Ref Number of Gaps (all)', 'Ref Gaps larger than 10bp', 'Query Number of Gaps (all)', 'Query Gaps larger than 10bp', 'Ref Gaps larger than 100bp', 'Query Gaps larger than 100bp', 'Ref Gaps larger than 1000bp', 'Query Gaps larger than 1000bp', 'Ref N to query bp', 'Ref unique bp', 'Shared seq bp', 'Aligned Variance in bp', 'Query unique bp', 'Query N to ref in bp', 'Total alignment Length', "Ref Chr Total Size (No N's)", 'Ref Identity within Alignment', 'Alignment Coverage of Ref Chr', 'Alignment Coverage of Query Main Chr']
# chr1	chr2	chr3	chr4	chr5	chr6	chr7	chr8	chr9	chr10	chr11	chr12	chr13	chr14	chr15	chr16	chr17	chr18	chr19	chr20	chr21	chr22	chrX	chrY
# Ref Number of Gaps (all)	165609	170672	137201	139495	127304	123905	119253	103879	90319	95484	92132	96419	71882	65255	63744	66458	64312	55079	53722	45779	33180	33888	89016	35422
# Ref Gaps larger than 10bp	18763	18015	13383	13788	12607	12484	14143	11382	10275	11050	9946	9907	7416	6801	6843	9996	8164	5861	7683	5898	4281	5000	10685	7320
# Query Number of Gaps (all)	171053	178311	142805	145896	131709	125787	124269	107404	95198	98327	94230	98479	74740	66865	66261	70208	64542	56834	54235	47098	35036	35142	97074	35425
# Query Gaps larger than 10bp	21270	20429	15560	15261	14357	13711	15879	12314	10949	12245	10997	11165	8273	7557	7551	10578	8707	6424	8220	6115	4377	5098	11746	7327
# Ref Gaps larger than 100bp	4479	3618	2374	2773	2396	2308	3573	2359	2207	2504	1971	1901	1638	1370	1455	2892	1826	1129	1990	1291	1027	1311	2703	3226
# Query Gaps larger than 100bp	4832	3701	2525	2840	2518	2331	3533	2183	2123	2354	1996	1887	1586	1328	1404	2723	1727	1148	1978	1104	909	1200	2534	3123
# Ref Gaps larger than 1000bp	1655	1187	718	912	828	688	1277	739	845	819	677	586	506	462	578	1127	598	323	667	405	326	481	1077	1430
# Query Gaps larger than 1000bp	1943	1068	662	832	725	633	1163	565	713	620	598	465	408	440	478	969	550	283	608	335	323	443	950	1371
# Ref N to query bp	18475471	1645301	195424	461888	272881	727457	376941	370500	16604167	534460	552880	137493	16381203	16475569	17349864	8533476	337994	283680	176858	500575	6621364	11659387	1147971	30813205
# Ref unique bp	8720120	8260400	6981350	6721519	8377245	5024550	8153166	6336318	6501557	6082908	7284509	6103971	3849601	4245909	4447223	4824479	6846475	6855876	5993312	4674499	3798511	3699846	10676764	4713798
# Shared seq bp	220917707	230534885	189497504	181435990	171933266	163553827	149955018	137307451	114437369	126144862	126357568	126059664	93347690	85325045	79377739	76802346	75807242	72457276	52358698	58788482	35871105	35177263	143853741	22309259
# Aligned Variance in bp	2830836	3039716	2455454	2501290	2254345	2128352	2064825	1984435	1639734	1708138	1694144	1618815	1250938	1134250	1110620	1219533	1004791	978685	831326	834315	588978	598637	1536778	758461
# Query unique bp	8724657	4682573	2722691	3241496	30017302	3922784	6402326	2323770	2009904	4145888	2765835	1956826	5205275	2098847	9776198	8134807	33191258	1233057	2981850	1090382	910924	5071519	2966721	5105610
# Query N to ref in bp	2495044	512888	454701	880917	712412	424267	2041529	9448	240403	1197562	8258	5774	402562	475733	1518735	355075	853093	421540	509942	65675	180762	278066	1094639	0
# Total alignment Length	223748543	233574601	191952958	183937280	174187611	165682179	152019843	139291886	116077103	127853000	128051712	127678479	94598628	86459295	80488359	78021879	76812033	73435961	53190024	59622797	36460083	35775900	145390519	23067720
# Ref Chr Total Size (No N's)	232468663	241835001	198934308	190658799	182564856	170706729	160173009	145628204	122578660	133935908	135336221	133782450	98448229	90705204	84935582	82846358	83658508	80291837	59183336	64297296	40258594	39475746	156067283	27781518
# Ref Identity within Alignment	0.9873481366088717	0.9869861021404464	0.9872080429205994	0.9864013972588918	0.9870579486849957	0.9871540076739334	0.9864173981550554	0.9857534056219183	0.9858737515184196	0.986639828553104	0.986769844982627	0.987321160052353	0.9867763621265205	0.9868811097754151	0.9862014828753062	0.9843693459369263	0.9869188334072605	0.9866729462422368	0.9843706406299045	0.9860067785816892	0.9838459501038437	0.983267031716882	0.9894299985269328	0.9671202442200616
# Alignment Coverage of Ref Chr	0.9624890516964001	0.9658428268619397	0.9649062543802148	0.9647458232441714	0.9541135945682777	0.9705661866439957	0.9490977534173688	0.956489760733436	0.9469601234015774	0.9545834415069632	0.9461747273111756	0.9543739033034602	0.9608972041538706	0.9531900176311825	0.9476400479601117	0.9417659494458405	0.9181616411327823	0.9146130384337825	0.898733116362349	0.9272986689829071	0.9056472016881663	0.9062754634199947	0.9315887110048555	0.8303261182488301
# Alignment Coverage of Query Main Chr	0.9624702675405165	0.9803465603096594	0.9860142189637698	0.9826823528325669	0.853004016607573	0.9768710541801775	0.9595869312962128	0.9835910091748613	0.9829794653022241	0.9685914929828803	0.9788573087981844	0.9849051460171286	0.9478449755617273	0.9762997850609829	0.8916939458308093	0.9055812453139156	0.6982703181125736	0.9834863637820976	0.946915604061919	0.9820404396877324	0.9756248473582743	0.8758423635040442	0.9800028566182547	0.8187786108351409

# %%
all_results = {}
for comparison in ['hg38toPantro6']:
    all_results[comparison] = collect_stats(comparison)
    print()
# Out:
# hg38toPantro6 identity 98.67%
# hg38toPantro6 coverage 91.46%

# %% [markdown]
# ### Calculate centromere sizes
# Parse a CSV with chromosome name, and two positions.  Output the distance between the positions.

# %%
centromeres = {}
lines = open(r"Unique Human Centromere Locations.txt", 'r').readlines()
for line_i in range(0, len(lines), 2):
    label1, start = lines[line_i].split('\t')
    label2, end = lines[line_i+1].split('\t')
    start, end = int(start), int(end)
    assert label1 == label2 and start < end, (label1, label2, start, end)
    centromeres[label1] = end - start
for c in chr_order:
    print(centromeres[c], end='\t')
# Out:
# 3370400	2076300	3157700	2077200	4186600	1549700	4162600	2802300	2600400	2862200	4463500	3252100	2049700	2306200	2779400	2481000	4171000	5434500	3408800	3163400	2244000	2516800	4574000	662700
